# %% [markdown]
# # Iris Prediction
#
# Iris Prediction Network
#
# Main Sources:
#
#   [Kaggle Dataset](https://www.kaggle.com/datasets/arshid/iris-flower-dataset/data),
#   [Pytorch Basic Layout](https://docs.pytorch.org/tutorials/beginner/basics/quickstart_tutorial.html),
#   [Tensor Board for Visualising](https://docs.pytorch.org/tutorials/intermediate/tensorboard_tutorial.html)

# %% [markdown]
# ## Setup: importing Packages + checking for a GPU

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import seaborn as sns
from torch.utils.tensorboard import SummaryWriter

device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using: {device}")
# Out:
# Using: mps

# %% [markdown]
# ## Defining the neural network
# Main things I changed from the reference:
# - Linear : 4 &rarr; 10 &rarr; 5 &rarr; 3 (Random numbers, not much thought beyond that)
# - ReLU &rarr; SiLU (I read somewhere that its better, more smooth)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear_silu_stack = nn.Sequential(
            nn.Linear(4, 10),
            nn.SiLU(),
            nn.Linear(10, 5),
            nn.SiLU(),
            nn.Linear(5, 3)
        )

    def forward(self, x):
        logits = self.linear_silu_stack(x)
        return logits
    
model = NeuralNetwork().to(device)
print(model)
# Out:
# NeuralNetwork(
#   (linear_silu_stack): Sequential(
#     (0): Linear(in_features=4, out_features=10, bias=True)
#     (1): SiLU()
#     (2): Linear(in_features=10, out_features=5, bias=True)
#     (3): SiLU()
#     (4): Linear(in_features=5, out_features=3, bias=True)
#   )
# )

# %% [markdown]
# ## Importing Data, changing variety to numbers, splitting into traindata and testdata

# %%
data_path = './Data/IRIS.csv'

df = pd.read_csv(data_path)

df["species"] = df["species"].map({
    "Iris-setosa": 0,
    "Iris-versicolor": 1,
    "Iris-virginica": 2,
})

df_tensor = torch.from_numpy(df.values).float()
X = df_tensor[:, :-1]
y = df_tensor[:, -1].long()

dataset = torch.utils.data.TensorDataset(X, y)
traindata, testdata = torch.utils.data.random_split(dataset, [0.80, 0.20])

print(X.size(), y.size(), len(traindata), len(testdata))
# Out:
# torch.Size([150, 4]) torch.Size([150]) 120 30

# %% [markdown]
# ## Batching

# %%
batch_size = 10 # Chose a small batch because the dataset is small
train_loader = torch.utils.data.DataLoader(traindata, batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(testdata, batch_size, shuffle=False)

# %% [markdown]
# ## Learning
# - Changed the optimisation model from SGD to AdamW (cause I read its better)

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=0.001) # learning rate adjusted because of the small dataset

def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        # if batch % 3 == 0:
        #     loss, current = loss.item(), (batch + 1) * len(X)
        #     print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}:")
    train(train_loader, model, loss_fn, optimizer)
    test(test_loader, model, loss_fn)

print("Done!")

torch.save(model.state_dict(), "./Data/model.pth")
print("Saved PyTorch Model State to model.pth")
# Out:
# Epoch 1:
# Accuracy: 40.0%, Avg loss: 1.120575
#
# Epoch 2:
# Accuracy: 40.0%, Avg loss: 1.105118
#
# Epoch 3:
# Accuracy: 40.0%, Avg loss: 1.089490
#
# Epoch 4:
# Accuracy: 40.0%, Avg loss: 1.074333
#
# Epoch 5:
# Accuracy: 43.3%, Avg loss: 1.058700
#
# Epoch 6:
# Accuracy: 50.0%, Avg loss: 1.039639
#
# Epoch 7:
# Accuracy: 60.0%, Avg loss: 1.017981
#
# Epoch 8:
# Accuracy: 63.3%, Avg loss: 0.989847
#
# Epoch 9:
# Accuracy: 63.3%, Avg loss: 0.956045
#
# Epoch 10:
# Accuracy: 86.7%, Avg loss: 0.914622
#
# Epoch 11:
# Accuracy: 80.0%, Avg loss: 0.868044
#
# Epoch 12:
# Accuracy: 80.0%, Avg loss: 0.816592
#
# Epoch 13:
# Accuracy: 76.7%, Avg loss: 0.757147
#
# Epoch 14:
# Accuracy: 76.7%, Avg loss: 0.703690
#
# Epoch 15:
# Accuracy: 76.7%, Avg loss: 0.646494
#
# Epoch 16:
# Accuracy: 76.7%, Avg loss: 0.595014
#
# Epoch 17:
# Accuracy: 80.0%, Avg loss: 0.550048
#
# Epoch 18:
# Accuracy: 80.0%, Avg loss: 0.510481
#
# Epoch 19:
# Accuracy: 80.0%, Avg loss: 0.479353
#
# Epoch 20:
# Accuracy: 80.0%, Avg loss: 0.452635
#
# Epoch 21:
# Accuracy: 90.0%, Avg loss: 0.432861
#
# Epoch 22:
# Accuracy: 96.7%, Avg loss: 0.415314
#
# Epoch 23:
# Accuracy: 96.7%, Avg loss: 0.397181
#
# Epoch 24:
# Accuracy: 96.7%, Avg loss: 0.381845
#
# Epoch 25:
# Accuracy: 96.7%, Avg loss: 0.360702
#
# Epoch 26:
# Accuracy: 96.7%, Avg loss: 0.357345
#
# Epoch 27:
# Accuracy: 96.7%, Avg loss: 0.333857
#
# Epoch 28:
# Accuracy: 100.0%, Avg loss: 0.325775
#
# Epoch 29:
# Accuracy: 100.0%, Avg loss: 0.314157
#
# Epoch 30:
# Accuracy: 96.7%, Avg loss: 0.295896
#
# Epoch 31:
# Accuracy: 100.0%, Avg loss: 0.291584
#
# Epoch 32:
# Accuracy: 96.7%, Avg loss: 0.282867
#
# Epoch 33:
# Accuracy: 96.7%, Avg loss: 0.263282
#
# Epoch 34:
# Accuracy: 96.7%, Avg loss: 0.261935
#
# Epoch 35:
# Accuracy: 100.0%, Avg loss: 0.245651
#
# Epoch 36:
# Accuracy: 100.0%, Avg loss: 0.236554
#
# Epoch 37:
# Accuracy: 96.7%, Avg loss: 0.235005
#
# Epoch 38:
# Accuracy: 96.7%, Avg loss: 0.238397
#
# Epoch 39:
# Accuracy: 96.7%, Avg loss: 0.210094
#
# Epoch 40:
# Accuracy: 100.0%, Avg loss: 0.213080
#
# Epoch 41:
# Accuracy: 96.7%, Avg loss: 0.212901
#
# Epoch 42:
# Accuracy: 100.0%, Avg loss: 0.197376
#
# Epoch 43:
# Accuracy: 96.7%, Avg loss: 0.196969
#
# Epoch 44:
# Accuracy: 100.0%, Avg loss: 0.186279
#
# Epoch 45:
# Accuracy: 96.7%, Avg loss: 0.198954
#
# Epoch 46:
# Accuracy: 100.0%, Avg loss: 0.175339
#
# Epoch 47:
# Accuracy: 100.0%, Avg loss: 0.171704
#
# Epoch 48:
# Accuracy: 96.7%, Avg loss: 0.175103
#
# Epoch 49:
# Accuracy: 96.7%, Avg loss: 0.174809
#
# Epoch 50:
# Accuracy: 100.0%, Avg loss: 0.165996
#
# Epoch 51:
# Accuracy: 100.0%, Avg loss: 0.155770
#
# Epoch 52:
# Accuracy: 100.0%, Avg loss: 0.157325
#
# Epoch 53:
# Accuracy: 96.7%, Avg loss: 0.169916
#
# Epoch 54:
# Accuracy: 100.0%, Avg loss: 0.150196
#
# Epoch 55:
# Accuracy: 100.0%, Avg loss: 0.150473
#
# Epoch 56:
# Accuracy: 100.0%, Avg loss: 0.147025
#
# Epoch 57:
# Accuracy: 96.7%, Avg loss: 0.157278
#
# Epoch 58:
# Accuracy: 100.0%, Avg loss: 0.136752
#
# Epoch 59:
# Accuracy: 100.0%, Avg loss: 0.145278
#
# Epoch 60:
# Accuracy: 96.7%, Avg loss: 0.148629
#
# Epoch 61:
# Accuracy: 100.0%, Avg loss: 0.137145
#
# Epoch 62:
# Accuracy: 100.0%, Avg loss: 0.132627
#
# Epoch 63:
# Accuracy: 96.7%, Avg loss: 0.145874
#
# Epoch 64:
# Accuracy: 96.7%, Avg loss: 0.142856
#
# Epoch 65:
# Accuracy: 100.0%, Avg loss: 0.128914
#
# Epoch 66:
# Accuracy: 100.0%, Avg loss: 0.126047
#
# Epoch 67:
# Accuracy: 100.0%, Avg loss: 0.132074
#
# Epoch 68:
# Accuracy: 96.7%, Avg loss: 0.133718
#
# Epoch 69:
# Accuracy: 100.0%, Avg loss: 0.126346
#
# Epoch 70:
# Accuracy: 100.0%, Avg loss: 0.126000
#
# Epoch 71:
# Accuracy: 100.0%, Avg loss: 0.121309
#
# Epoch 72:
# Accuracy: 96.7%, Avg loss: 0.133493
#
# Epoch 73:
# Accuracy: 96.7%, Avg loss: 0.113275
#
# Epoch 74:
# Accuracy: 96.7%, Avg loss: 0.127818
#
# Epoch 75:
# Accuracy: 100.0%, Avg loss: 0.122626
#
# Epoch 76:
# Accuracy: 100.0%, Avg loss: 0.117872
#
# Epoch 77:
# Accuracy: 100.0%, Avg loss: 0.113763
#
# Epoch 78:
# Accuracy: 100.0%, Avg loss: 0.108941
#
# Epoch 79:
# Accuracy: 96.7%, Avg loss: 0.142389
#
# Epoch 80:
# Accuracy: 100.0%, Avg loss: 0.117352
#
# Epoch 81:
# Accuracy: 100.0%, Avg loss: 0.113218
#
# Epoch 82:
# Accuracy: 96.7%, Avg loss: 0.122032
#
# Epoch 83:
# Accuracy: 100.0%, Avg loss: 0.114576
#
# Epoch 84:
# Accuracy: 96.7%, Avg loss: 0.120408
#
# Epoch 85:
# Accuracy: 100.0%, Avg loss: 0.113396
#
# Epoch 86:
# Accuracy: 100.0%, Avg loss: 0.110441
#
# Epoch 87:
# Accuracy: 96.7%, Avg loss: 0.120557
#
# Epoch 88:
# Accuracy: 100.0%, Avg loss: 0.108067
#
# Epoch 89:
# Accuracy: 100.0%, Avg loss: 0.107291
#
# Epoch 90:
# Accuracy: 100.0%, Avg loss: 0.115632
#
# Epoch 91:
# Accuracy: 100.0%, Avg loss: 0.106371
#
# Epoch 92:
# Accuracy: 100.0%, Avg loss: 0.112293
#
# Epoch 93:
# Accuracy: 100.0%, Avg loss: 0.102730
#
# Epoch 94:
# Accuracy: 100.0%, Avg loss: 0.103404
#
# Epoch 95:
# Accuracy: 100.0%, Avg loss: 0.108635
#
# Epoch 96:
# Accuracy: 100.0%, Avg loss: 0.107984
#
# Epoch 97:
# Accuracy: 100.0%, Avg loss: 0.102134
#
# Epoch 98:
# Accuracy: 100.0%, Avg loss: 0.110725
#
# Epoch 99:
# Accuracy: 96.7%, Avg loss: 0.118045
#
# Epoch 100:
# Accuracy: 100.0%, Avg loss: 0.096481
#
# Done!
# Saved PyTorch Model State to model.pth

# %% [markdown]
# ## Evaluating the model using softmax + argmax prediction of the most likely variation (just a little bit more visual)

# %%
model = NeuralNetwork().to(device)
model.load_state_dict(torch.load("./Data/model.pth", weights_only=True))

classes = [
    "Iris-setosa",
    "Iris-versicolor",
    "Iris-virginica"
]

# Rotate throuh i through basically the whole test set

for i in range(len(testdata)):
    total = 0.0
    random_row = np.random.randint(0, len(testdata))
    example = testdata[random_row][0].unsqueeze(0).to(device)
    model.eval()
    with torch.no_grad(): # both of these turn off processes that are only needed for training
        prediction = model(example)
        probabilities = torch.softmax(prediction, dim=1)
        likely_variety = classes[probabilities.argmax()]
        total = total + max(probabilities.flatten().cpu().numpy())
        print(f"Predicted variety: {likely_variety}, Probabilities: {probabilities.cpu().numpy()}")
        print(f"Percentage \"correct\": {total/(1):.2%}")
        i += 1
# Out:
# Predicted variety: Iris-virginica, Probabilities: [[2.6995863e-06 7.2480634e-02 9.2751676e-01]]
# Percentage "correct": 92.75%
# Predicted variety: Iris-versicolor, Probabilities: [[7.5596989e-05 5.1887828e-01 4.8104608e-01]]
# Percentage "correct": 51.89%
# Predicted variety: Iris-setosa, Probabilities: [[9.8866189e-01 1.1338102e-02 1.2230471e-10]]
# Percentage "correct": 98.87%
# Predicted variety: Iris-versicolor, Probabilities: [[8.9108601e-04 9.5479673e-01 4.4312235e-02]]
# Percentage "correct": 95.48%
# Predicted variety: Iris-virginica, Probabilities: [[6.2916024e-07 2.2539860e-02 9.7745961e-01]]
# Percentage "correct": 97.75%
# Predicted variety: Iris-setosa, Probabilities: [[9.9740332e-01 2.5966614e-03 2.7267858e-12]]
# Percentage "correct": 99.74%
# Predicted variety: Iris-versicolor, Probabilities: [[7.4873416e-04 9.4726259e-01 5.1988687e-02]]
# Percentage "correct": 94.73%
# Predicted variety: Iris-versicolor, Probabilities: [[0.00154556 0.98736596 0.01108842]]
# Percentage "correct": 98.74%
# Predicted variety: Iris-virginica, Probabilities: [[2.6995863e-06 7.2480634e-02 9.2751676e-01]]
# Percentage "correct": 92.75%
# Predicted variety: Iris-versicolor, Probabilities: [[6.7229755e-04 9.7997159e-01 1.9356100e-02]]
# Percentage "correct": 98.00%
# Predicted variety: Iris-setosa, Probabilities: [[9.9594146e-01 4.0585417e-03 1.3797010e-11]]
# Percentage "correct": 99.59%
# Predicted variety: Iris-versicolor, Probabilities: [[7.4873416e-04 9.4726259e-01 5.1988687e-02]]
# Percentage "correct": 94.73%
# Predicted variety: Iris-virginica, Probabilities: [[2.6995863e-06 7.2480634e-02 9.2751676e-01]]
# Percentage "correct": 92.75%
# Predicted variety: Iris-versicolor, Probabilities: [[8.9108601e-04 9.5479673e-01 4.4312235e-02]]
# Percentage "correct": 95.48%
# Predicted variety: Iris-versicolor, Probabilities: [[0.00154556 0.98736596 0.01108842]]
# Percentage "correct": 98.74%
# Predicted variety: Iris-setosa, Probabilities: [[9.9758208e-01 2.4178999e-03 1.8521224e-12]]
# Percentage "correct": 99.76%
# Predicted variety: Iris-versicolor, Probabilities: [[8.9108601e-04 9.5479673e-01 4.4312235e-02]]
# Percentage "correct": 95.48%
# Predicted variety: Iris-virginica, Probabilities: [[2.3353837e-06 8.4154695e-02 9.1584301e-01]]
# Percentage "correct": 91.58%
# Predicted variety: Iris-setosa, Probabilities: [[9.9547511e-01 4.5248712e-03 1.4026219e-11]]
# Percentage "correct": 99.55%
# Predicted variety: Iris-virginica, Probabilities: [[8.2033926e-09 4.2470992e-03 9.9575293e-01]]
# Percentage "correct": 99.58%
# Predicted variety: Iris-versicolor, Probabilities: [[7.4873416e-04 9.4726259e-01 5.1988687e-02]]
# Percentage "correct": 94.73%
# Predicted variety: Iris-virginica, Probabilities: [[6.2916024e-07 2.2539860e-02 9.7745961e-01]]
# Percentage "correct": 97.75%
# Predicted variety: Iris-setosa, Probabilities: [[9.980020e-01 1.997954e-03 5.293830e-13]]
# Percentage "correct": 99.80%
# Predicted variety: Iris-setosa, Probabilities: [[9.980020e-01 1.997954e-03 5.293830e-13]]
# Percentage "correct": 99.80%
# Predicted variety: Iris-versicolor, Probabilities: [[6.7229755e-04 9.7997159e-01 1.9356100e-02]]
# Percentage "correct": 98.00%
# Predicted variety: Iris-setosa, Probabilities: [[9.9547511e-01 4.5248712e-03 1.4026219e-11]]
# Percentage "correct": 99.55%
# Predicted variety: Iris-setosa, Probabilities: [[9.9758208e-01 2.4178999e-03 1.8521224e-12]]
# Percentage "correct": 99.76%
# Predicted variety: Iris-setosa, Probabilities: [[9.9758208e-01 2.4178999e-03 1.8521224e-12]]
# Percentage "correct": 99.76%
# Predicted variety: Iris-setosa, Probabilities: [[9.9594146e-01 4.0585417e-03 1.3797010e-11]]
# Percentage "correct": 99.59%
# Predicted variety: Iris-versicolor, Probabilities: [[8.9108601e-04 9.5479673e-01 4.4312235e-02]]
# Percentage "correct": 95.48%

# %% [markdown]
# # Summary
# This may be overfitted. I am getting results around 99% most of the time using the weights.
# Things I could still improve:
# - Stratify the split
# - Benchmark the model using different variables
# - Visualise the training better using e.g. sns or TensorBoard
# - Test the model further using e.g. a larger dataset
#
# I also wanted to present it in a much fancier way but using a Jupyter Notebook ended up being a lot simpler.
